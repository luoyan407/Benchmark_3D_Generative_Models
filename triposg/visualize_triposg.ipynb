# %%
# !python -m scripts.inference_triposg --image-input assets/example_data/hjswed.png --output-path ./output.ply
# Out:
# Running cells with 'triposg (Python 3.10.19)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n triposg ipykernel --update-deps --force-reinstall'
